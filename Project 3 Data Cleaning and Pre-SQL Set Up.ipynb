# %%
# Import dependencies
import pandas as pd
import numpy as np
import glob
pd.set_option('max_colwidth', 400)

# %%
# Read the data into a Pandas DataFrame
asthma_df = pd.read_csv('Resources/asthma.csv')
asthma_df.head()
# Out:
#   geographic_area  year       gender age_adjusted_rate
# 0  Statewide Only  2016  All Genders               6.5
# 1  Statewide Only  2017  All Genders               6.5
# 2  Statewide Only  2018  All Genders               6.5
# 3  Statewide Only  2019  All Genders               6.5
# 4        Alcona**  2016  All Genders        Suppressed

# %%
asthma_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 336 entries, 0 to 335
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   geographic_area    336 non-null    object
#  1   year               336 non-null    int64
#  2   gender             336 non-null    object
#  3   age_adjusted_rate  336 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 10.6+ KB

# %%
cancer_df = pd.read_csv('Resources/county_cancer_data.csv')
cancer_df.head()
# Out:
#   county    year  diagnosed_number  diagnosed_adjusted_rate  \
# 0  Wayne  2015.0           10130.0                    494.7
# 1  Wayne  2016.0            9739.0                    470.9
# 2  Wayne  2017.0            9787.0                    472.0
# 3  Wayne  2018.0            9812.0                    468.3
# 4  Wayne  2019.0            9994.0                    470.8
#
#    diagnosed_michigan_rate  death_number  death_adjusted_rate  \
# 0                    453.2        3721.0                181.3
# 1                    461.3        3759.0                180.2
# 2                    446.9        3616.0                174.4
# 3                    445.5        3554.0                167.7
# 4                    442.3        3615.0                168.2
#
#    death_michigan_rate  Unnamed: 8  Unnamed: 9  Unnamed: 10  Unnamed: 11  \
# 0                166.6         NaN         NaN          NaN          NaN
# 1                166.9         NaN         NaN          NaN          NaN
# ...

# %%
cancer_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121 entries, 0 to 120
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   county                   18 non-null     object
#  1   year                     18 non-null     float64
#  2   diagnosed_number         18 non-null     float64
#  3   diagnosed_adjusted_rate  18 non-null     float64
#  4   diagnosed_michigan_rate  18 non-null     float64
#  5   death_number             18 non-null     float64
#  6   death_adjusted_rate      18 non-null     float64
#  7   death_michigan_rate      18 non-null     float64
#  8   Unnamed: 8               0 non-null      float64
#  9   Unnamed: 9               0 non-null      float64
#  10  Unnamed: 10              0 non-null      float64
#  11  Unnamed: 11              0 non-null      float64
#  12  Unnamed: 12              0 non-null      float64
# dtypes: float64(12), object(1)
# ...

# %%
air_quality_df = pd.read_csv('Resources/air_quality.csv')
air_quality_df.head()
# Out:
#    state_code  county_code  site_num  parameter_code  POC   latitude  \
# 0          26          125         1           88101    1  42.463063
# 1          26          161         8           88101    1  42.240565
# 2          26          163         1           88101    2  42.228620
# 3          26          163        15           88101    2  42.302786
# 4          26          163        19           88101    1  42.430840
#
#    longitude  datum            parameter_name sample_duration  ...  \
# 0 -83.183199  WGS84  PM2.5 - Local Conditions         24 HOUR  ...
# 1 -83.599602  WGS84  PM2.5 - Local Conditions   24-HR BLK AVG  ...
# 2 -83.208200  WGS84  PM2.5 - Local Conditions         24 HOUR  ...
# 3 -83.106530  WGS84  PM2.5 - Local Conditions   24-HR BLK AVG  ...
# 4 -83.000138  WGS84  PM2.5 - Local Conditions         24 HOUR  ...
#
#   seventy_fifth_percentile fiftieth_percentile tenth_percentile  \
# 0                     13.1                 7.4              2.9
# ...

# %%
air_quality_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95 entries, 0 to 94
# Data columns (total 55 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   state_code                        95 non-null     int64
#  1   county_code                       95 non-null     int64
#  2   site_num                          95 non-null     int64
#  3   parameter_code                    95 non-null     int64
#  4   POC                               95 non-null     int64
#  5   latitude                          95 non-null     float64
#  6   longitude                         95 non-null     float64
#  7   datum                             95 non-null     object
#  8   parameter_name                    95 non-null     object
#  9   sample_duration                   95 non-null     object
#  10  pollutant_standard                95 non-null     object
#  11  metric_used                       95 non-null     object
# ...
